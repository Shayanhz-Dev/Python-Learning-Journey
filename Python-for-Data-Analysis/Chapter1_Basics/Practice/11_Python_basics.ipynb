# %% [markdown]
# ## None

# %%
a = None

# %%
a is None

# %%
b = 5

# %%
b is not None

# %%
def add_and_maybe_multiply(a, b, c=None):
    result = a + b

    if c is not None:
        result = result * c

    return result

# %%
add_and_maybe_multiply(4,2)

# %%
add_and_maybe_multiply(4,2,2)
