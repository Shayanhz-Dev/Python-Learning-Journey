# %% [markdown]
# ## While Loops

# %%
x = 256
total = 0
while x > 0:
    if total > 500:
        break
    total += x 
    x = x//2

print(total)

# %% [markdown]
# ## Pass

# %%
x = 22
if x < 0:
    print("negative!")
elif x == 0:
    print("equal to zero")
    pass
else:
    print("positive!")

# %% [markdown]
# ## Range

# %%
range(10)

# %%
list(range(10))

# %%
list(range(5, 0, -1))

# %%
seq = [1, 2, 3, 4]
for i in range(len(seq)):
    print(f"element {i}: {seq[i]}")

# %%
total = 0 
for i in range (100_000):
    if i %3 == 0 or i % 5 == 0:
        total += i
print(total)
