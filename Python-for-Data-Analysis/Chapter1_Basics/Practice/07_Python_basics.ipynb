# %% [markdown]
# # Numerical types

# %%
ival = 17239871

# %%
ival ** 6

# %%
fval = 7.243

# %%
fval2 = 678e-5

# %%
3/2

# %%
3//2

# %% [markdown]
# ## strings

# %%
a = "one way of writing a string"

# %%
b = "another way"

# %%
c = """
This is a longer string that 
spans multiple lines
"""

# %%
c.count("\n")

# %%
a = "this is a string"

# %%
b = a.replace("string", "longer string")

# %%
b

# %%
a = 5.6

# %%
s = str(a)

# %%
print(s)

# %%
s = "python"

# %%
list(s)

# %%
s[:3]

# %%
s = "12\\13"

# %%
print(s)

# %%
s = "this\has\no\special\charecter"

# %%
s

# %%
a = "this is the first half "

# %%
b = "and is the second half"

# %%
a + b

# %%
template = "{0:.2f} {1:s} are worth US${2:d}"

# %%
template.format(88.46, "Argemtine pesos", 1)

# %%
amount = 10

# %%
rate = 88.46

# %%
currency = "Pesos"

# %%
result = f"{amount} {currency} is worth us${amount / rate}"

# %%
f"{amount} {currency} is worth {amount / rate:.2f}"
