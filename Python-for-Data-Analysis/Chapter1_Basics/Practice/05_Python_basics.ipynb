# %% [markdown]
# ## Binary operators and comparisons ##

# %%
5 -7

# %%
12 + 21.5

# %%
5 <= 2

# %%
a = [1, 2, 3]

# %%
b = a

# %%
c = list(a)

# %%
a is b

# %%
a is not c

# %%
a == c

# %%
b is c

# %%
a is c

# %%
b is a

# %%
a = None

# %%
a is None
