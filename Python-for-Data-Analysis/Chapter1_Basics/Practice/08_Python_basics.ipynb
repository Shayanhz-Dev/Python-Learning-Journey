# %% [markdown]
# ## Bytes and Unicode

# %%
val = "español"

# %%
val

# %%
val_utf8 = val.encode("utf-8")

# %%
val_utf8

# %%
type(val_utf8)

# %%
val_utf8.decode("latin1")

# %%
val.encode("latin1")

# %%
val.encode("utf-16")

# %%
val.encode("utf-16le")
