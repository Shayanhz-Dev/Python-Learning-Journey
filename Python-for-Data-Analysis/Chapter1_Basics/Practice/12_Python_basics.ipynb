# %% [markdown]
# ## Dates and times

# %%
from datetime import datetime , date, time

# %%
dt = datetime(2011, 10, 29, 20, 30, 32)

# %%
dt.day

# %%
dt.month

# %%
dt.year

# %%
dt.hour

# %%
dt.minute

# %%
dt.second

# %%
dt.date()

# %%
dt.time()

# %%
dt.strftime("%Y-%m-%d %H:%M")

# %%
datetime.strptime("20091031", "%Y%m%d")

# %%
dt_hour = dt.replace(minute=0, second=0)

# %%
dt_hour

# %%
dt

# %%
dt2 = datetime(2011, 11, 15, 22, 30)

# %%
delta = dt2 - dt

# %%
delta

# %%
type(delta)

# %%
dt

# %%
dt + delta
