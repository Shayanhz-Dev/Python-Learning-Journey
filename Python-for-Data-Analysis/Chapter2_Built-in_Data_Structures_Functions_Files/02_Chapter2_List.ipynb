# %% [markdown]
# ## list

# %%
a_list = [2, 3, 7, None]

# %%
tup = ("foo", "bar", "baz")

# %%
b_list = list(tup)

# %%
b_list

# %%
b_list[1] = "peekaboo"

# %%
b_list

# %%
gen = range(10)

# %%
gen

# %%
list(gen)

# %% [markdown]
# ## Adding and Removing Elements

# %%
b_list.append('dwarf')

# %%
b_list

# %%
b_list.insert(1, "red")

# %%
b_list

# %%
b_list.pop(2)

# %%
b_list

# %%
b_list.append("foo")

# %%
b_list

# %%
b_list.remove('foo')

# %%
b_list

# %%
"dwarf" in b_list

# %%
"dwarf" not in b_list

# %% [markdown]
# ## Concatenating and Combining Lists

# %%
[4, None, 'foo'] + [7, 8, (2, 3)]

# %%
x = [4, None, 'foo']

# %%
x.extend([7, 8, (2, 3)])

# %%
x

# %%
a = [7, 2, 5, 1, 3]

# %%
a.sort()

# %%
a

# %%
b = ['saw', 'small', 'he', 'foxes', 'six']

# %%
b.sort(key=len)

# %%
b

# %%
seq = [7, 2, 3, 7, 5, 6, 0, 1]

# %%
seq[1:5]

# %%
seq[3:5] = [6, 3]

# %%
seq

# %%
seq[:5]

# %%
seq[3:]

# %%
seq[-4:]

# %%
seq[-6:-2]

# %%
seq[::2]

# %%
seq[::-1]
