# %% [markdown]
# # The Numpy ndarray: A multidimensional Array Object

# %%
import numpy as np

# %%
data = np.array([[1.5, -0.1, 3], [0, -3, 6.5]])

# %%
data

# %%
data * 10

# %%
data + data

# %%
data.shape

# %%
data.dtype
